# %% [markdown]
# ![kekw](logogogogo.png)

# %% [markdown]
# # \begin{align*} \text{SIMULAÇÃO DE SISTEMAS ELÉTRICOS POR QUADRIPOLOS} \end{align*}

# %% [markdown]
# ### Alunos:
# - Àdson Vital Correia
# - Beatriz Barros Monteiro
# - Danilo de Oliveira Melo
# - Davi Ramalho Costa Souza
# - João Pedro Dantas de Queiroz
# - Yan Abrantes Cavalcante

# %% [markdown]
# ## Questão 1

# %% [markdown]
# ![kekw](transmissionline.jpg)
#
# \begin{align*} \text{Figura 1 - Linha de Transmissão} \end{align*}

# %% [markdown]
# ### Considerando os seguintes parâmetros:
#
# - Impedância série de Thévenin $R_f$ = 4 &Omega; e $X_f$ = 0,38 &Omega;.
#
# - Parâmetros das Linhas de Transmissão, de acordo com o modelo da Figura 2: $R$ = 0,172 &Omega;/km, $L$ = 2, 18mH/km e $C$ = 0, 0136&mu; F/km
#
# - Considere que as LT1, LT2 e LT3 possuem 100 km, a LT4 e LT5 possui 100 km e a LT6 possui 120 km.
#
# - Considere os seguintes parâmetros para os Transformadores, conforme Figura 3: $Rt_1$ = 7, 6m&Omega;, $X_1$ = 3, 8m&Omega;, $Rt_2$ = 33, 9m&Omega;, $X_2$ = 0, 85m&Omega;.
#
# - Para as cargas, considere:
#
# <br>
#
# - $R_1$ = 8530 &Omega;
# - $L_1$ = 52H
# - $R_2$ = 1050.55 &Omega;
# - $L_2$ = 6,02H
# - $R_3$ = 505 &Omega;
# - $L_3$ = 2,7H

# %% [markdown]
# - Para a modelagem das Linhas de Transmissão, utilizaremos o modelo &pi;, que se dispõe da seguinte maneira:
#
#
# ![Alt text](modelopi.jpg)
#
# \begin{align*} \text{Figura 2 - Modelo $\pi$ de Linha de Transmissão} \end{align*}
#
#
# - Parâmetros das Linhas de Transmissão, de acordo com o modelo da Figura 2: $R$ = 0,172 &Omega;/km, $L$ = 2, 18mH/km e $C$ = 0, 0136&mu; F/km
#
#
# - Considere que as LT1, LT2 e LT3 possuem 100 km, a LT4 e LT5 possui 100 km e a LT6 possui 120 km.
#
#
# - Considere os seguintes parâmetros para os Transformadores, conforme Figura 3: $Rt_1$ = 7, 6m&Omega;, $X_1$ = 3, 8m&Omega;, $Rt_2$ = 33, 9m&Omega;, $X_2$ = 0, 85m&Omega;.

# %% [markdown]
# - Para a modelagem dos Transformadores, utilizaremos o seguinte modelo:
# <br>
#
#
# ![kekw](modelotransf.jpg)
#
#
# \begin{align*} \text{Figura 3 - Modelo de Transformador} \end{align*}
#
# - Considere os seguintes parâmetros para os Transformadores, conforme Figura 3: $Rt_1$ = 7, 6m&Omega;, $X_1$ = 3, 8m&Omega;, $Rt_2$ = 33, 9m&Omega;, $X_2$ = 0, 85m&Omega;.
#
# - E para cada um dos transformadores presentes na linha de transmissão, T1, T2 e T3 adotaremos, respectivamente:
#
# <br>
# $Rm_1$ = 4320 &Omega;
# $Xm_1$ = 5050 &Omega;
# $Rm_2$ = 432000 &Omega;
# $Xm_2$ = 505000 &Omega;
# $Rm_3$ = 402000 &Omega;
# $Xm_3$ = 607000 &Omega;

# %% [markdown]
# ### Simulação do Sistema Elétrico
#
# - Para a simulação do sistema elétrico, faz-se necessário a criação de matrizes de transferência $[T]$ de cada elemento. Utilizando da teoria de quadripolos, isto é, um circuito de duas portas, para cada um dos componentes, teremos diferentes parâmetros de transmissão, que são fundamentados na seguinte equação:
#
# <br>
#
#
# $$
# \begin{bmatrix}  V_1  \\  I_1  \\ \end{bmatrix}=\begin{bmatrix}  A & B \\  C & D \\ \end{bmatrix}\begin{bmatrix}  V_2  \\ I_2 \\ \end{bmatrix}
# $$
#
#
# <br>
#
# A partir desta equação, iremos obter os parâmetros de transmissão dos componentes da linha de transmissão. Desse modo, obteremos:
#
# - Para Cargas Série:
#
#
# $$
# \begin{bmatrix}  V_1  \\  I_1  \\ \end{bmatrix}= \begin{bmatrix}  1 & Z \\  0 & 1 \\ \end{bmatrix} \begin{bmatrix}  V_2  \\I_2\\ \end{bmatrix}
# $$
#
#
#
# E sua implementação via software ocorrerá da seguinte maneira:
#
# - Primeiramente, para todos os parâmetros de transmissão, iremos criar uma classe chamada "Quadripole", que será utilizada em todas as outras funções:

# %%
import numpy as np

class Quadripole:
    def __init__(self, V1 = None, I1 = None, V2 = None, I2  = None):
        self.tensions = [V1, V2]
        self.currents = [I1, I2]
        pass

# %% [markdown]
# E agora, a função para o parâmetro para cargas em série:

# %%
class SeriesImpedance(Quadripole):
    def __init__(self, z, V1 = None, I1 = None, V2 = None, I2  = None):
        super().__init__(V1, I1, V2, I2)
        self.net_mtrx = np.array([[1, z], 
                                 [0 ,1]])
        pass

# %% [markdown]
# - Para Cargas em Derivação:
#
#
# $$
# \begin{bmatrix}  V_1  \\  I_1  \\ \end{bmatrix}=\begin{bmatrix}  1 & 0 \\  Y & 1 \\ \end{bmatrix}\begin{bmatrix}  V_2  \\  I_2\\ \end{bmatrix} $$
#
#
# <br>
#
#
# E sua implementação via software ocorrerá da seguinte maneira:

# %% [markdown]
# - Para o Modelo $\pi$ de Linha de Transmissão:
#
#
# $$
# \begin{bmatrix}
#   V_1  \\
#   I_1  \\
# \end{bmatrix}= \begin{bmatrix}
#   (1+Y_2Z) & Z \\
#   (Y_1+Y_2+Y_1Y_2Z) & (1+Y_1Z) \\
# \end{bmatrix}\begin{bmatrix}
#   V_2  \\
#   I_2  \\
# \end{bmatrix}
# $$
#
#
#
#
# E sua implementação via software ocorrerá da seguinte maneira:

# %%
class PiCircuit(Quadripole):
    def __init__(self, z, y1, y2, V1 = None, I1 = None, V2 = None, I2  = None):
        super().__init__(V1, I1, V2, I2)
        self.net_mtrx = np.array([1 + y2*z, z], 
                                 [y1 + y2 + y1*y2*z , 1+y1*z])
        pass

# %% [markdown]
# - Para o Transformador:
#
#
# $$
# \begin{bmatrix}  V_1  \\  I_1  \\ \end{bmatrix}=\begin{bmatrix} \frac{1}{n} \cdot (1+YZ_1) & n\cdot(Z_1+Z_2+YZ_1Z_2) \\ \frac{1}{n}\cdot Y & n \cdot (1+YZ_2) \\ \end{bmatrix}\begin{bmatrix}  V_2  \\  I_2  \\ \end{bmatrix}
# $$

# %% [markdown]
# E sua implementação via software ocorrerá da seguinte maneira:

# %%
class Transformer(Quadripole):
    def __init__(self, n, z1, z2, y, V1 = None, I1 = None, V2 = None, I2  = None):
        super().__init__(V1, I1, V2, I2)
        self.net_mtrx = np.array([1/n * (1+ y*z1), n*(z1 + z2 + y*z1*z2)], 
                                 [1/n * y, n*(1+y*z2)])
        pass

# %% [markdown]
# Com todas as matrizes de transferência $[T]$ realizadas, serão implementadas as funções que descrevem as associações presentes na linha de transmissão, da seguinte maneira:

# %%
import numpy as np
from quadripoles import Quadripole, SeriesImpedance, ShuntAdmittance, PiCircuit, Transformer

class Network:
    def __init__(self, v1=None, v2=None, i1=None, i2=None, resultant_mtrx = None):
        self.resultant_mtrx = resultant_mtrx
        self.tensions = [v1, v2]
        self.currents = [i1, i2]
        pass
    
    #Associação em Paralelo
    def parallel_connection(self, matA, matB):
        A = np.dot(matA[0], matB[0][::-1])/(matA[0][1] + matB[0][1])
        B = (matA[0][1]*matB[0][1])/(matA[0][1] + matB[0][1])
        C = matA[1][0] + matB[1][0] + (matA[0][0]-matB[0][0])*(matB[1][1]-matA[1][1])/((matA[0][1] + matB[0][1]))
        D = np.dot(matA[:,1], matB[::-1, 1])/(matA[0][1] + matB[0][1])
        
        return np.array([[A, B],
                        [C, D]])
    
    #Associação em Cascata
    def cascade_connection(self, *args):
        if len(args) < 2:
            raise ValueError('This function needs at least 2 arguments')
            
        result = np.dot(args[0],args[1])
        for i in range(2, len(args)):
                result = np.dot(result, args[i])
                
        return result
    
    def set_resultant_matrix(self, result):
        self.resultant_mtrx = result
        
    def set_tension1(self):
        try:
            self.tensions[0] = self.resultant_mtrx[0][0]*self.tensions[1] + self.resultant_mtrx[0][1]*self.currents[1]
        except TypeError:
                raise ValueError('Missing data!')
             
    def set_tension2(self):
        try:
            self.tensions[1] = (self.tensions[0] - self.resultant_mtrx[0][1]*self.currents[1])/self.resultant_mtrx[0][0]
        except TypeError:
            try:
                self.tensions[1] = (self.currents[0] - self.resultant_mtrx[1][1]*self.currents[1])/self.resultant_mtrx[1][0]
            except TypeError:
                raise ValueError('Missing data!')
            
    def set_current1(self):
        try:
            self.currents[0] = self.resultant_mtrx[1][0]*self.tensions[1] + self.resultant_mtrx[1][1]*self.currents[1]
        except TypeError:
                raise ValueError('Missing data!')
    
    def set_current2(self):
        try:
            self.currents[1] = (self.currents[0] + self.resultant_mtrx[1][0]*self.tensions[1])/self.resultant_mtrx[1][1]
        except TypeError:
            try:
                self.currents[1] = (self.tensions[0] - self.resultant_mtrx[0][0]*self.tensions[1])/self.resultant_mtrx[0][1]
            except TypeError:
                raise ValueError('Missing data!')

# %% [markdown]
# ### Obtendo as tensões e correntes fasoriais para cada carga:
#
# - Com todas as funções definidas, podemos obter a tensão fasorial de saída $V_{ac}$, a corrente fasorial na carga $Z_3$, além das tensões e corrente fasoriais nas impedâncias $Z_1$ e $Z_2$. Para isso, foi considerada uma tensão no gerador de $69kV_RMS$

# %%
import numpy as np
from cmath import polar, atan
from network import Network
from quadripoles import Quadripole, SeriesImpedance, ShuntAdmittance, PiCircuit, Transformer

network = Network(v1=69e3)

s_imped_th = SeriesImpedance(z=4+0.38j)

t1 = Transformer(n= 230e3/69e3, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j,
                 y=(4320 + 5050j)/(4320*5050j))

network.set_resultant_matrix(network.cascade_connection(s_imped_th.net_mtrx, t1.net_mtrx))

rkm = 0.172
xlkm = 120*np.pi*2.18e-3j
xckm = 1/(120*np.pi*0.0136e-6j)

lt1 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
lt2 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
lt3 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)

ltpl1 = network.parallel_connection(network.parallel_connection(lt1.net_mtrx, lt2.net_mtrx), lt3.net_mtrx)

network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, ltpl1))

z1=ShuntAdmittance(z=8530 + 120*np.pi*52j)

network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, z1.net_mtrx))

lt4 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
lt5 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)

lt2pl = network.parallel_connection(lt4.net_mtrx, lt5.net_mtrx)

network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, lt2pl))

t2 = Transformer(n= 138e3/230e3, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j,
                 y= (432000 + 505000j)/(432000*505000j))

network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, t2.net_mtrx))

z2=ShuntAdmittance(z=1050.55 + 120*np.pi*6.02j)


network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, z2.net_mtrx))

lt6=PiCircuit(z= rkm*120 + xlkm*120, y1=1/(2*xckm) * 120, y2=1/(2*xckm) * 120)

network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, lt6.net_mtrx))

t3=Transformer(n=69e3/1e3, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j,
                 y=(402000 + 607000j)/(402000*607000j))


network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, t3.net_mtrx))

z3=ShuntAdmittance(z=505 + 120*np.pi*2.7j)


def fasor(nmcomplexo):
    modulo, fase = polar(nmcomplexo)
    fase = np.rad2deg(fase)
    return modulo, fase

vz3 = 69e3/(network.resultant_mtrx[0][0] + network.resultant_mtrx[0][1]/(505 + 120*np.pi*2.7j))
iz3 = vz3/(505 + 120*np.pi*2.7j)

fasorvz3 = fasor(vz3)
fasoriz3 = fasor(iz3)


print('\nTensão Z3: ', fasorvz3[0], f'∠{fasorvz3[1]}°')
print('Corrente Z3: ', fasoriz3[0], f'∠{fasoriz3[1]}°')


net2 = Network()

net2.set_resultant_matrix(net2.cascade_connection(z2.net_mtrx, lt6.net_mtrx))
net2.set_resultant_matrix(net2.cascade_connection(net2.resultant_mtrx, t3.net_mtrx))

vz2 = net2.resultant_mtrx[0][0]*vz3 + net2.resultant_mtrx[0][1]*iz3
IS2  = net2.resultant_mtrx[1][0]*vz3 + net2.resultant_mtrx[1][1]*iz3

iz2 = vz2/(1050.55 + 120*np.pi*6.02j)

fasorvz2 = fasor(vz2)
fasoriz2 = fasor(iz2)

print('\nTensão Z2: ', fasorvz2[0], f'∠{fasorvz2[1]}°')
print('Corrente Z2: ', fasoriz2[0], f'∠{fasoriz2[1]}°')


net3 = Network()

net3.set_resultant_matrix(net3.cascade_connection(lt2pl, t2.net_mtrx))

vz1 = net3.resultant_mtrx[0][0]*vz2 + net3.resultant_mtrx[0][1]*IS2
iz1 = vz1/(8530 + 120*np.pi*52j)

fasorvz1 = fasor(vz1)
fasoriz1 = fasor(iz1)

print('\nTensão Z1: ', fasorvz1[0], f'∠{fasorvz1[1]}°')
print('Corrente Z1: ', fasoriz1[0], f'∠{fasoriz1[1]}°')

# %% [markdown]
# - Tensão $Z_3$ =  18469.93176819392 ∠-14.107697861791008°
# - Corrente $Z_3$ =  16.254960697260866 ∠-77.72025600641955°
#
# - Tensão $Z_2$ = 113275.15852994779 ∠0.4051895959930387°
# - Corrente $Z_2$ = 45.29475845019168 ∠-64.75529475900548°
#
# - Tensão $Z_1$ = 213349.4602820473 ∠0.750475597550065°
# - Corrente $Z_1$ = 9.979416001400171 ∠-65.73443636523083°

# %% [markdown]
# ### Simulação no ORCad Capture

# %% [markdown]
# ![kekw](orcadmontage.png)

# %% [markdown]
# ![kekw](graficoslindos.jpg)

# %% [markdown]
# - Através da simulação no ORCAD foram encontrados os mesmos valores para as tensões e correntes de cada uma das carga, respectivamente $Z_1$, $Z_2$ e $Z_3$.

# %% [markdown]
# ### Ajuste TAP:
#
# - Objetivando obter valores de tensão nas cargas de, respectivamente, $500kV$, $230kV$ e $69kV$, implementamos o seguinte código:

# %%
import numpy as np
from cmath import polar, atan
from network import Network
from quadripoles import Quadripole, SeriesImpedance, ShuntAdmittance, PiCircuit, Transformer

vcondical3 = 69E3
vcondical2 = 230E3
vcondical1 = 500E3

aux = []
aux1 = []
aux2 = []

# Considera-se uma variável por vez

def findn1n2n3():
        # n1=3.33
        # n2=0.1
        n3=0.257

        while(1):

            network = Network(v1=69e3)
            s_imped_th = SeriesImpedance(z=4+0.38j)
            t1 = Transformer(n= 8.02, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j, y=(4320 + 5050j)/(4320*5050j))

            network.set_resultant_matrix(network.cascade_connection(s_imped_th.net_mtrx, t1.net_mtrx))

            rkm = 0.172
            xlkm = 120*np.pi*2.18e-3j
            xckm = 1/(120*np.pi*0.0136e-6j)

            lt1 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
            lt2 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
            lt3 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)

            ltpl1 = network.parallel_connection(network.parallel_connection(lt1.net_mtrx, lt2.net_mtrx), lt3.net_mtrx)

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, ltpl1))

            z1=ShuntAdmittance(z=8530 + 120*np.pi*52j)

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, z1.net_mtrx))

            lt4 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)
            lt5 = PiCircuit(z= rkm*100 + xlkm*100, y1=1/(2*xckm) * 100, y2=1/(2*xckm) * 100)

            lt2pl = network.parallel_connection(lt4.net_mtrx, lt5.net_mtrx)

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, lt2pl))

            t2 = Transformer(n= 0.5, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j,
                            y= (432000 + 505000j)/(432000*505000j))

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, t2.net_mtrx))

            z2=ShuntAdmittance(z=1050.55 + 120*np.pi*6.02j)


            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, z2.net_mtrx))

            lt6=PiCircuit(z= rkm*120 + xlkm*120, y1=1/(2*xckm) * 120, y2=1/(2*xckm) * 120)

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, lt6.net_mtrx))

            t3=Transformer(n=n3, z1= 7.6e-3 + 3.8e-3j, z2= 33.9e-3 + 0.85e-3j,
                            y=(402000 + 607000j)/(402000*607000j))

            network.set_resultant_matrix(network.cascade_connection(network.resultant_mtrx, t3.net_mtrx))

            z3=ShuntAdmittance(z=505 + 120*np.pi*2.7j)


            def fasor(nmcomplexo):
                modulo, fase = polar(nmcomplexo)
                fase = np.rad2deg(fase)
                return modulo, fase

            vz3 = 69e3/(network.resultant_mtrx[0][0] + network.resultant_mtrx[0][1]/(505 + 120*np.pi*2.7j))
    
            iz3 = vz3/(505 + 120*np.pi*2.7j)

            fasorvz3 = fasor(vz3)
            fasoriz3 = fasor(iz3)

            net2 = Network()

            net2.set_resultant_matrix(net2.cascade_connection(z2.net_mtrx, lt6.net_mtrx))
            net2.set_resultant_matrix(net2.cascade_connection(net2.resultant_mtrx, t3.net_mtrx))

            vz2 = net2.resultant_mtrx[0][0]*vz3 + net2.resultant_mtrx[0][1]*iz3
            IS2  = net2.resultant_mtrx[1][0]*vz3 + net2.resultant_mtrx[1][1]*iz3

            iz2 = vz2/(1050.55 + 120*np.pi*6.02j)

            fasorvz2 = fasor(vz2)
            fasoriz2 = fasor(iz2)

            net3 = Network()

            net3.set_resultant_matrix(net3.cascade_connection(lt2pl, t2.net_mtrx))

            vz1 = net3.resultant_mtrx[0][0]*vz2 + net3.resultant_mtrx[0][1]*IS2
            iz1 = vz1/(8530 + 120*np.pi*52j)

            fasorvz1 = fasor(vz1)
            fasoriz1 = fasor(iz1)

            aux.append(fasorvz1[0])
            aux1.append(fasorvz2[0])
            aux2.append(fasorvz3[0])
            
            with open('dadosn1n2n3.txt','at') as f:
                f.write(f'n1:{8.02}, Tensao1: {fasorvz1[0]}, {fasorvz1[1]}\n')
                f.write(f'n2:{0.5}, Tensao2: {fasorvz2[0]}, {fasorvz2[1]}\n')
                f.write(f'n3:{n3}, Tensao3: {fasorvz3[0]}, {fasorvz3[1]}\n')
                f.write('-='*32)
                f.write('\n')
                
            # if fasorvz1[0] < 500e3:
            #     n1 += 0.1
            # if fasorvz2[0] < 230e3:
            #     n2 += 0.1
            if fasorvz3[0] < 69e3:
                n3 += 0.01
    
findn1n2n3()

# %% [markdown]
# - A partir disso foram obtidos os seguinte valores de TAP:
#
# \begin{align*} \text{$TAP_{new}:8.02$} \end{align*}
# \begin{align*} \text{$TAP_{new}:0.5$} \end{align*}
# \begin{align*} \text{$TAP_{new}:0.267$} \end{align*}

# %% [markdown]
# - E os valores de tensão nas cargas obtidos podem ser observados no gráfico(na ordem $Z_1$, $Z_2$ e $Z_3$):

# %% [markdown]
# ![kekw](ajustetap.png)

# %% [markdown]
# Como os valores obtidos foram próximos do desejado, podemos concluir que o ajuste TAP foi satisfatório.
